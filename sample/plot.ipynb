# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
chain = pd.read_csv("test_spec.csv")

# %%
chain.plot(subplots=True,figsize=(6,16))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f67e14386a0>,
# ...
#       dtype=object)

# %%
chain.hist(bins=64,figsize=(6,16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f67be710048>,
# ...
#       dtype=object)
